# %%
import cv2
from find_plate import find_plate
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
i = 0
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
for _ in range(80):
    img_path = "sample/" + str(i%80+1+1000)[1:] + ".jpg"
    try:
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        result = find_plate(img)
        print(img_path)
        plt.imshow(result,cmap = "gray")
        plt.show()
    except:
        pass

    i += 1
# Out:
# sample/001.jpg
# sample/002.jpg
# sample/003.jpg
# sample/004.jpg
# sample/005.jpg
# sample/014.jpg
# sample/016.jpg
# sample/017.jpg
# sample/018.jpg
# sample/019.jpg
# sample/020.jpg
# sample/022.jpg
# sample/023.jpg
# sample/024.jpg
# /var/folders/k5/mdqvz0d17yg6tk40xj22_cq80000gn/T/ipykernel_23078/4053691928.py:7: UserWarning: Attempting to set identical bottom == top == -0.5 results in singular transformations; automatically expanding.
#   plt.imshow(result,cmap = "gray")
# sample/025.jpg
# sample/026.jpg
# sample/027.jpg
# sample/029.jpg
# sample/030.jpg
# sample/031.jpg
# sample/032.jpg
# sample/033.jpg
# sample/034.jpg
# sample/035.jpg
# sample/039.jpg
# sample/040.jpg
# sample/042.jpg
# sample/044.jpg
# sample/047.jpg
# sample/048.jpg
# sample/050.jpg
# sample/051.jpg
# sample/052.jpg
# sample/053.jpg
# sample/054.jpg
# sample/055.jpg
# sample/057.jpg
# sample/058.jpg
# sample/061.jpg
# sample/062.jpg
# sample/063.jpg
# sample/064.jpg
# sample/080.jpg
